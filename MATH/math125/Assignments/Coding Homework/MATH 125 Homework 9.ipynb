# %%
library(expm)
library(ggplot2)

h <- (1/252)
k <- 2*sqrt(h)

a <- (1/2)*(h/k^2)
b <- (1- (h/k^2))

M <- diag(b, 81)
M[abs(row(M) - col(M)) == 1] <- a

f <- M %^% 252
f0 <- dnorm(mean = )

solution <- pnorm(2, 1)
solution
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected symbol
# 1: import library
#            ^
# Traceback:
